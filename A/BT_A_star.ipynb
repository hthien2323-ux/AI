# %%
from collections import deque

class Graph:
    def __init__(self, adjac_lis):
        self.adjac_lis = adjac_lis

    def get_neighbors(self, v):
        return self.adjac_lis[v]

    # This is heuristic function which is having equal values for all nodes
    def h(self, n):
        H = {
            'A': 1,
            'B': 1,
            'C': 1,
            'D': 1
        }
        return H[n]

    def a_star_algorithm(self, start, stop):
        open_lst = set([start])
        closed_lst = set([])

        poo = {}
        poo[start] = 0

        # par contains an adjac mapping of all nodes
        par = {}
        par[start] = start

        while len(open_lst) > 0:
            n = None

            # it will find a node with the lowest value of f() -
            for v in open_lst:
                if n == None or poo[v] + self.h(v) < poo[n] + self.h(n):
                    n = v;

            if n == None:
                print('Path does not exist!')
                return None

            # if the current node is the stop then we start again from start
            if n == stop:
                reconst_path = []

                while par[n] != n:
                    reconst_path.append(n)
                    n = par[n]

                reconst_path.append(start)
                reconst_path.reverse()

                print('Path found: {}'.format(reconst_path))
                return reconst_path

            # for all the neighbors of the current node do
            for (m, weight) in self.get_neighbors(n):
                # if the current node is not present in both open_lst and closed_lst
                # add it to open_lst and note n as it's par
                if m not in open_lst and m not in closed_lst:
                    open_lst.add(m)
                    par[m] = n
                    poo[m] = poo[n] + weight

                else:
                    if poo[m] > poo[n] + weight:
                        poo[m] = poo[n] + weight
                        par[m] = n

                        if m in closed_lst:
                            closed_lst.remove(m)
                            open_lst.add(m)

            open_lst.remove(n)
            closed_lst.add(n)

        print('Path does not exist!')
        return None

# Khởi tạo dữ liệu và chạy thuật toán
adjac_lis = {
    'A': [('B', 1), ('C', 3), ('D', 7)],
    'B': [('C', 1), ('D', 5)],
    'C': [('D', 12)]
}

graph1 = Graph(adjac_lis)
graph1.a_star_algorithm('A', 'C')
# Out:
# Path found: ['A', 'B', 'C']
# ['A', 'B', 'C']

# %%
class Graph:
    def __init__(self, graph):
        self.graph = graph

    def get_neighbors(self, node):
        return self.graph[node]

    def heuristic(self, node):
        return 1

    def a_star(self, start, goal):
        open_list = [start]
        closed_list = []

        g = {start: 0}
        parent = {start: start}

        while open_list:
            current = open_list[0]
            for node in open_list:
                if g[node] + self.heuristic(node) < g[current] + self.heuristic(current):
                    current = node

            if current == goal:
                path = []
                while parent[current] != current:
                    path.append(current)
                    current = parent[current]
                path.append(start)
                path.reverse()

                print("Đường đi tìm được:", path)
                return path

            for neighbor, cost in self.get_neighbors(current):
                if neighbor not in open_list and neighbor not in closed_list:
                    open_list.append(neighbor)
                    parent[neighbor] = current
                    g[neighbor] = g[current] + cost
                else:
                    if g[neighbor] > g[current] + cost:
                        g[neighbor] = g[current] + cost
                        parent[neighbor] = current

                        if neighbor in closed_list:
                            closed_list.remove(neighbor)
                            open_list.append(neighbor)

            open_list.remove(current)
            closed_list.append(current)

        print("Không tìm thấy đường đi!")
        return None


graph_data = {
    'A': [('B', 1), ('C', 3), ('D', 7)],
    'B': [('C', 1), ('D', 5)],
    'C': [('D', 12)],
    'D': []
}

g = Graph(graph_data)
g.a_star('A', 'C')
# Out:
# Đường đi tìm được: ['A', 'B', 'C']
# ['A', 'B', 'C']

# %%
# Bài 2

class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, u, v, w):
        if u not in self.graph:
            self.graph[u] = []
        self.graph[u].append((v, w))

    def get_neighbors(self, node):
        return self.graph.get(node, [])

    def heuristic(self, node, goal):
        return 1

    def a_star(self, start, goal):
        open_list = [start]
        closed_list = []

        g = {start: 0}
        parent = {start: start}

        while open_list:
            current = open_list[0]
            for node in open_list:
                if g[node] + self.heuristic(node, goal) < g[current] + self.heuristic(current, goal):
                    current = node

            if current == goal:
                path = []
                while parent[current] != current:
                    path.append(current)
                    current = parent[current]
                path.append(start)
                path.reverse()

                print("Đường đi:", path)
                print("Chi phí:", g[goal])
                return path

            for neighbor, cost in self.get_neighbors(current):
                if neighbor not in open_list and neighbor not in closed_list:
                    open_list.append(neighbor)
                    parent[neighbor] = current
                    g[neighbor] = g[current] + cost
                else:
                    if g.get(neighbor, float('inf')) > g[current] + cost:
                        g[neighbor] = g[current] + cost
                        parent[neighbor] = current

                        if neighbor in closed_list:
                            closed_list.remove(neighbor)
                            open_list.append(neighbor)

            open_list.remove(current)
            closed_list.append(current)

        print("Không tìm thấy đường đi")
        return None


g = Graph()
g.add_edge('A', 'B', 1)
g.add_edge('A', 'C', 3)
g.add_edge('A', 'D', 7)
g.add_edge('B', 'C', 1)
g.add_edge('B', 'D', 5)
g.add_edge('C', 'D', 12)

start = input("Nhập đỉnh bắt đầu: ")
goal = input("Nhập đỉnh đích: ")

g.a_star(start, goal)
# Out:
# Nhập đỉnh bắt đầu: A
# Nhập đỉnh đích: D
# Đường đi: ['A', 'B', 'D']
# Chi phí: 6
# ['A', 'B', 'D']
